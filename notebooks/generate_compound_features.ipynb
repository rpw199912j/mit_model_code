# %% [markdown]
# # Import packages and functions

# %%
import sys
# force the notebook to look for files in the upper level directory
sys.path.insert(1, '../')

# %%
import pandas as pd
from data.compound_featurizer import read_new_struct, generate_formula_from_structure, composition_featurizer, structure_featurizer, handbuilt_featurizer

# %% [markdown]
# # Test the featurizer on a single structure

# %%
TEST_STRUCT_PATH = "../data/Structures/Metals/SrRuO3_CollCode_75561.cif"

SrRuO3_df = read_new_struct(TEST_STRUCT_PATH)
SrRuO3_df
# Out:
#   Compound                                          structure
# 0   SrRuO3  [[2.86047311 1.96178    2.79521159] Sr2+, [0.0...

# %%
# generate composition-based features
SrRuO3_df = composition_featurizer(SrRuO3_df)
# generate structure-based features
SrRuO3_df = structure_featurizer(SrRuO3_df)
# generate handbuilt features
SrRuO3_df = handbuilt_featurizer(SrRuO3_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='StrToComposition', max=1.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='ElementProperty', max=1.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='CompositionToOxidComposition', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=0.0, description='OxidationStates', max=1.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='StructureToOxidStructure', max=1.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='EwaldEnergy', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='StructuralHeterogeneity', max=1.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=0.0, description='GlobalInstabilityIndex', max=1.0, style=ProgressStyle(des…
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/tqdm/std.py:670: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# HBox(children=(FloatProgress(value=0.0, description='Handbuilt Featurizer', max=1.0, style=ProgressStyle(descr…

# %% [markdown]
# Here is a print out of the final featurized dataframe.

# %%
SrRuO3_df
# Out:
#   Compound                                          structure  composition  \
# 0   SrRuO3  [[2.86047311 1.96178    2.79521159] Sr2+, [0.0...  (Sr, Ru, O)
#
#    MagpieData minimum Number  MagpieData maximum Number  \
# 0                        8.0                       44.0
#
#    MagpieData range Number  MagpieData mean Number  MagpieData avg_dev Number  \
# 0                     36.0                    21.2                      15.84
#
#    MagpieData mode Number  MagpieData minimum MendeleevNumber  ...  \
# 0                     8.0                                 8.0  ...
#
#    max_xx_dists  min_xx_dists  avg_xx_dists        v_m        v_x    iv  \
# 0      3.579973      2.760023      2.947568 -44.758483  23.738172  45.0
#
#    iv_p1  est_hubbard_u  est_charge_trans  volume_per_site
# 0   59.0      10.330721          8.527722        12.089967
#
# [1 rows x 170 columns]

# %% [markdown]
# The following shows all the columns/features in the dataframe.

# %%
list(SrRuO3_df.columns)
# Out:
# ['Compound',
#  'structure',
#  'composition',
#  'MagpieData minimum Number',
#  'MagpieData maximum Number',
#  'MagpieData range Number',
#  'MagpieData mean Number',
#  'MagpieData avg_dev Number',
#  'MagpieData mode Number',
#  'MagpieData minimum MendeleevNumber',
#  'MagpieData maximum MendeleevNumber',
#  'MagpieData range MendeleevNumber',
#  'MagpieData mean MendeleevNumber',
#  'MagpieData avg_dev MendeleevNumber',
#  'MagpieData mode MendeleevNumber',
#  'MagpieData minimum AtomicWeight',
#  'MagpieData maximum AtomicWeight',
#  'MagpieData range AtomicWeight',
#  'MagpieData mean AtomicWeight',
#  'MagpieData avg_dev AtomicWeight',
#  'MagpieData mode AtomicWeight',
#  'MagpieData minimum MeltingT',
#  'MagpieData maximum MeltingT',
#  'MagpieData range MeltingT',
#  'MagpieData mean MeltingT',
#  'MagpieData avg_dev MeltingT',
#  'MagpieData mode MeltingT',
#  'MagpieData minimum Column',
#  'MagpieData maximum Column',
#  'MagpieData range Column',
#  'MagpieData mean Column',
#  'MagpieData avg_dev Column',
#  'MagpieData mode Column',
#  'MagpieData minimum Row',
#  'MagpieData maximum Row',
#  'MagpieData range Row',
#  'MagpieData mean Row',
#  'MagpieData avg_dev Row',
#  'MagpieData mode Row',
#  'MagpieData minimum CovalentRadius',
#  'MagpieData maximum CovalentRadius',
#  'MagpieData range CovalentRadius',
#  'MagpieData mean CovalentRadius',
#  'MagpieData avg_dev CovalentRadius',
#  'MagpieData mode CovalentRadius',
#  'MagpieData minimum Electronegativity',
#  'MagpieData maximum Electronegativity',
#  'MagpieData range Electronegativity',
#  'MagpieData mean Electronegativity',
#  'MagpieData avg_dev Electronegativity',
#  'MagpieData mode Electronegativity',
#  'MagpieData minimum NsValence',
#  'MagpieData maximum NsValence',
#  'MagpieData range NsValence',
#  'MagpieData mean NsValence',
#  'MagpieData avg_dev NsValence',
#  'MagpieData mode NsValence',
#  'MagpieData minimum NpValence',
#  'MagpieData maximum NpValence',
#  'MagpieData range NpValence',
#  'MagpieData mean NpValence',
#  'MagpieData avg_dev NpValence',
#  'MagpieData mode NpValence',
#  'MagpieData minimum NdValence',
#  'MagpieData maximum NdValence',
#  'MagpieData range NdValence',
#  'MagpieData mean NdValence',
#  'MagpieData avg_dev NdValence',
#  'MagpieData mode NdValence',
#  'MagpieData minimum NfValence',
#  'MagpieData maximum NfValence',
#  'MagpieData range NfValence',
#  'MagpieData mean NfValence',
#  'MagpieData avg_dev NfValence',
#  'MagpieData mode NfValence',
#  'MagpieData minimum NValence',
#  'MagpieData maximum NValence',
#  'MagpieData range NValence',
#  'MagpieData mean NValence',
#  'MagpieData avg_dev NValence',
#  'MagpieData mode NValence',
#  'MagpieData minimum NsUnfilled',
#  'MagpieData maximum NsUnfilled',
#  'MagpieData range NsUnfilled',
#  'MagpieData mean NsUnfilled',
#  'MagpieData avg_dev NsUnfilled',
#  'MagpieData mode NsUnfilled',
#  'MagpieData minimum NpUnfilled',
#  'MagpieData maximum NpUnfilled',
#  'MagpieData range NpUnfilled',
#  'MagpieData mean NpUnfilled',
#  'MagpieData avg_dev NpUnfilled',
#  'MagpieData mode NpUnfilled',
#  'MagpieData minimum NdUnfilled',
#  'MagpieData maximum NdUnfilled',
#  'MagpieData range NdUnfilled',
#  'MagpieData mean NdUnfilled',
#  'MagpieData avg_dev NdUnfilled',
#  'MagpieData mode NdUnfilled',
#  'MagpieData minimum NfUnfilled',
#  'MagpieData maximum NfUnfilled',
#  'MagpieData range NfUnfilled',
#  'MagpieData mean NfUnfilled',
#  'MagpieData avg_dev NfUnfilled',
#  'MagpieData mode NfUnfilled',
#  'MagpieData minimum NUnfilled',
#  'MagpieData maximum NUnfilled',
#  'MagpieData range NUnfilled',
#  'MagpieData mean NUnfilled',
#  'MagpieData avg_dev NUnfilled',
#  'MagpieData mode NUnfilled',
#  'MagpieData minimum GSvolume_pa',
#  'MagpieData maximum GSvolume_pa',
#  'MagpieData range GSvolume_pa',
#  'MagpieData mean GSvolume_pa',
#  'MagpieData avg_dev GSvolume_pa',
#  'MagpieData mode GSvolume_pa',
#  'MagpieData minimum GSbandgap',
#  'MagpieData maximum GSbandgap',
#  'MagpieData range GSbandgap',
#  'MagpieData mean GSbandgap',
#  'MagpieData avg_dev GSbandgap',
#  'MagpieData mode GSbandgap',
#  'MagpieData minimum GSmagmom',
#  'MagpieData maximum GSmagmom',
#  'MagpieData range GSmagmom',
#  'MagpieData mean GSmagmom',
#  'MagpieData avg_dev GSmagmom',
#  'MagpieData mode GSmagmom',
#  'MagpieData minimum SpaceGroupNumber',
#  'MagpieData maximum SpaceGroupNumber',
#  'MagpieData range SpaceGroupNumber',
#  'MagpieData mean SpaceGroupNumber',
#  'MagpieData avg_dev SpaceGroupNumber',
#  'MagpieData mode SpaceGroupNumber',
#  'composition_oxid',
#  'minimum oxidation state',
#  'maximum oxidation state',
#  'range oxidation state',
#  'std_dev oxidation state',
#  'structure_oxid',
#  'ewald_energy_per_atom',
#  'mean absolute deviation in relative bond length',
#  'max relative bond length',
#  'min relative bond length',
#  'minimum neighbor distance variation',
#  'maximum neighbor distance variation',
#  'range neighbor distance variation',
#  'mean neighbor distance variation',
#  'avg_dev neighbor distance variation',
#  'mean absolute deviation in relative cell size',
#  'gii',
#  'struct_ordered',
#  'struct_disordered',
#  'max_mm_dists',
#  'min_mm_dists',
#  'avg_mm_dists',
#  'max_mx_dists',
#  'min_mx_dists',
#  'avg_mx_dists',
#  'max_xx_dists',
#  'min_xx_dists',
#  'avg_xx_dists',
#  'v_m',
#  'v_x',
#  'iv',
#  'iv_p1',
#  'est_hubbard_u',
#  'est_charge_trans',
#  'volume_per_site']

# %% [markdown]
# # Test the featurizer on the entire collection of structures

# %%
# get the initial dataframe
df = generate_formula_from_structure()
# manually correct the Pymatgen naming from TiPbO3 to PbTiO3
df.Compound[df.Compound == "TiPbO3"] = "PbTiO3"
# Out:
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/io/cif.py:1123: UserWarning: Issues encountered while parsing CIF: Some fractional co-ordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: %s" % "\n".join(self.warnings))

# %%
df
# Out:
#              Compound  Label  \
# 0              CaCrO3      0
# 1          Ce(FeSb3)4      0
# 2            Sm2Mo2O7      0
# 3          La(As3Ru)4      0
# 4                RuO2      0
# ..                ...    ...
# 400            GdNiO3      2
# 401          Sr3Fe2O7      2
# 402         Cu(IrS2)2      2
# 403          Hg2Ru2O7      2
# 404  Ca1.2La2.8Mn4O12      2
#
#                                       struct_file_path  \
# 0    ../data/Structures/Metals/CaCrO3_CollCode_2458...
# 1    ../data/Structures/Metals/CeFe4Sb12_CollCode_6...
# 2    ../data/Structures/Metals/Sm2Mo2O7_CollCode_29...
# 3    ../data/Structures/Metals/LaRu4As12_CollCode_6...
# 4    ../data/Structures/Metals/RuO2_CollCode_15071.cif
# ..                                                 ...
# 400  ../data/Structures/MIT_materials/HighT/GdNiO3_...
# 401  ../data/Structures/MIT_materials/HighT/Sr3Fe2O...
# 402  ../data/Structures/MIT_materials/HighT/CuIr2S4...
# 403  ../data/Structures/MIT_materials/HighT/Hg2Ru2O...
# 404  ../data/Structures/MIT_materials/HighT/La0.7Ca...
#
#                                              structure
# 0    [[2.58311502 2.83194208 1.872325  ] Ca2+, [0.0...
# 1    [[0. 0. 0.] Ce4+, [4.5675 4.5675 4.5675] Ce4+,...
# 2    [[5.2098 2.6049 2.6049] Sm3+, [2.6049 5.2098 2...
# 3    [[0. 0. 0.] La4+, [4.25405 4.25405 4.25405] La...
# 4    [[2.24595 2.24595 1.5533 ] Ru4+, [0. 0. 0.] Ru...
# ..                                                 ...
# 400  [[2.70922445 3.0886867  1.87779   ] Gd3+, [5.1...
# 401  [[  2.52970118   2.62135184 -13.41229736] Sr2+...
# 402  [[2.46185 2.46185 2.46185] Cu2+, [0. 0. 0.] Cu...
# 403  [[5.100545  2.5502725 2.5502725] Hg2+, [2.5502...
# 404  [[2.84066461 1.9315075  2.76859685] Ca2+:0.300...
#
# [405 rows x 4 columns]

# %% [markdown]
# ## Generate compositional, structural and handbuilt features

# %%
df = composition_featurizer(df)
df = structure_featurizer(df)
df = handbuilt_featurizer(df)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='StrToComposition', max=405.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='ElementProperty', max=405.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='CompositionToOxidComposition', max=405.0, style=ProgressS…
# HBox(children=(FloatProgress(value=0.0, description='OxidationStates', max=405.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='StructureToOxidStructure', max=405.0, style=ProgressStyle…
# HBox(children=(FloatProgress(value=0.0, description='EwaldEnergy', max=405.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='StructuralHeterogeneity', max=405.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='GlobalInstabilityIndex', max=405.0, style=ProgressStyle(d…
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/matminer/featurizers/structure.py:3567: UserWarning: GII extremely large. Table parameters may not be suitable or structure may be unusual.
#   warnings.warn("GII extremely large. Table parameters may "
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/tqdm/std.py:670: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# HBox(children=(FloatProgress(value=0.0, description='Handbuilt Featurizer', max=405.0, style=ProgressStyle(des…
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/analysis/ewald.py:304: UserWarning: Per atom energies for charged structures not supported in EwaldSummation
#   warn('Per atom energies for charged structures not supported in EwaldSummation')
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/analysis/ewald.py:304: UserWarning: Per atom energies for charged structures not supported in EwaldSummation
#   warn('Per atom energies for charged structures not supported in EwaldSummation')
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/analysis/ewald.py:304: UserWarning: Per atom energies for charged structures not supported in EwaldSummation
#   warn('Per atom energies for charged structures not supported in EwaldSummation')
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/analysis/ewald.py:304: UserWarning: Per atom energies for charged structures not supported in EwaldSummation
#   warn('Per atom energies for charged structures not supported in EwaldSummation')
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/analysis/ewald.py:304: UserWarning: Per atom energies for charged structures not supported in EwaldSummation
#   warn('Per atom energies for charged structures not supported in EwaldSummation')
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/analysis/ewald.py:304: UserWarning: Per atom energies for charged structures not supported in EwaldSummation
#   warn('Per atom energies for charged structures not supported in EwaldSummation')
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/analysis/ewald.py:304: UserWarning: Per atom energies for charged structures not supported in EwaldSummation
#   warn('Per atom energies for charged structures not supported in EwaldSummation')
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/analysis/ewald.py:304: UserWarning: Per atom energies for charged structures not supported in EwaldSummation
#   warn('Per atom energies for charged structures not supported in EwaldSummation')
# /Users/jasonrpw/PycharmProjects/mit_model_code/venv/lib/python3.7/site-packages/pymatgen/analysis/ewald.py:304: UserWarning: Per atom energies for charged structures not supported in EwaldSummation
#   warn('Per atom energies for charged structures not supported in EwaldSummation')

# %%
df
# Out:
#              Compound  Label  \
# 0              CaCrO3      0
# 1          Ce(FeSb3)4      0
# 2            Sm2Mo2O7      0
# 3          La(As3Ru)4      0
# 4                RuO2      0
# ..                ...    ...
# 400            GdNiO3      2
# 401          Sr3Fe2O7      2
# 402         Cu(IrS2)2      2
# 403          Hg2Ru2O7      2
# 404  Ca1.2La2.8Mn4O12      2
#
#                                       struct_file_path  \
# 0    ../data/Structures/Metals/CaCrO3_CollCode_2458...
# 1    ../data/Structures/Metals/CeFe4Sb12_CollCode_6...
# 2    ../data/Structures/Metals/Sm2Mo2O7_CollCode_29...
# 3    ../data/Structures/Metals/LaRu4As12_CollCode_6...
# 4    ../data/Structures/Metals/RuO2_CollCode_15071.cif
# ..                                                 ...
# 400  ../data/Structures/MIT_materials/HighT/GdNiO3_...
# 401  ../data/Structures/MIT_materials/HighT/Sr3Fe2O...
# 402  ../data/Structures/MIT_materials/HighT/CuIr2S4...
# 403  ../data/Structures/MIT_materials/HighT/Hg2Ru2O...
# 404  ../data/Structures/MIT_materials/HighT/La0.7Ca...
#
#                                              structure      composition  \
# 0    [[2.58311502 2.83194208 1.872325  ] Ca2+, [0.0...      (Ca, Cr, O)
# 1    [[0. 0. 0.] Ce4+, [4.5675 4.5675 4.5675] Ce4+,...     (Ce, Fe, Sb)
# 2    [[5.2098 2.6049 2.6049] Sm3+, [2.6049 5.2098 2...      (Sm, Mo, O)
# 3    [[0. 0. 0.] La4+, [4.25405 4.25405 4.25405] La...     (La, As, Ru)
# 4    [[2.24595 2.24595 1.5533 ] Ru4+, [0. 0. 0.] Ru...          (Ru, O)
# ..                                                 ...              ...
# 400  [[2.70922445 3.0886867  1.87779   ] Gd3+, [5.1...      (Gd, Ni, O)
# 401  [[  2.52970118   2.62135184 -13.41229736] Sr2+...      (Sr, Fe, O)
# 402  [[2.46185 2.46185 2.46185] Cu2+, [0. 0. 0.] Cu...      (Cu, Ir, S)
# 403  [[5.100545  2.5502725 2.5502725] Hg2+, [2.5502...      (Hg, Ru, O)
# 404  [[2.84066461 1.9315075  2.76859685] Ca2+:0.300...  (Ca, La, Mn, O)
#
#      MagpieData minimum Number  MagpieData maximum Number  \
# 0                          8.0                       24.0
# 1                         26.0                       58.0
# 2                          8.0                       62.0
# 3                         33.0                       57.0
# 4                          8.0                       44.0
# ..                         ...                        ...
# 400                        8.0                       64.0
# 401                        8.0                       38.0
# 402                       16.0                       77.0
# 403                        8.0                       80.0
# 404                        8.0                       57.0
#
#      MagpieData range Number  MagpieData mean Number  \
# 0                       16.0               13.600000
# 1                       32.0               45.529412
# 2                       54.0               24.000000
# 3                       24.0               37.000000
# 4                       36.0               20.000000
# ..                       ...                     ...
# 400                     56.0               23.200000
# 401                     30.0               18.500000
# 402                     61.0               35.285714
# 403                     72.0               27.636364
# 404                     49.0               18.980000
#
#      MagpieData avg_dev Number  ...  max_xx_dists  min_xx_dists  avg_xx_dists  \
# 0                     6.720000  ...      3.283740      2.677252      2.813798
# 1                     9.190311  ...      3.760981      2.904930      3.477261
# 2                    20.363636  ...      3.073782      2.687974      2.898260
# 3                     5.647059  ...      3.611906      2.620495      3.256348
# 4                    16.000000  ...      2.776388      2.467313      2.673363
# ..                         ...  ...           ...           ...           ...
# 400                  18.240000  ...      3.226412      2.717248      2.837820
# 401                  12.250000  ...      3.586772      2.756961      2.847590
# 402                  23.836735  ...      3.760108      3.203055      3.484365
# 403                  24.991736  ...      3.654839      2.684031      3.051351
# 404                  13.176000  ...      3.516261      2.747250      2.906344
#
#            v_m        v_x        iv    iv_p1  est_hubbard_u  est_charge_trans  \
# 0   -46.438514  25.057295   49.1600   69.460      16.458029          7.076892
# 1   -63.767409  26.543117       NaN      NaN            NaN               NaN
# 2   -43.966874  23.324578   40.3300   54.417      10.178178         12.128367
# 3   -67.463957  26.631662  110.0000  178.410      65.025073               NaN
# 4   -44.781726  25.598980   45.0000   59.000       9.927380         10.334715
# ..         ...        ...       ...      ...            ...               ...
# 400 -37.163808  23.507399   35.1870   54.920      15.921411         10.413110
# 401 -44.794374  24.763775   54.9100   75.000      16.452849         -0.397557
# 402 -28.508956  21.335783   28.0000   40.000       7.864049         20.488443
# 403 -52.293109  27.009665   59.0000   76.000      13.007450          5.125164
# 404 -39.888114  22.934073   38.9306   57.570      14.915598          8.843086
#
#      volume_per_site
# 0          10.539100
# 1          22.420575
# 2          12.854952
# 3          18.114187
# 4          10.447064
# ..               ...
# 400        10.837428
# 401        12.949911
# 402        17.052054
# 403        12.063048
# 404        11.576092
#
# [405 rows x 172 columns]

# %% [markdown]
# Drop unnecessary columns

# %%
df_output = df.drop(columns=["structure", "structure_oxid", "composition", "composition_oxid"])
df_output
# Out:
#              Compound  Label  \
# 0              CaCrO3      0
# 1          Ce(FeSb3)4      0
# 2            Sm2Mo2O7      0
# 3          La(As3Ru)4      0
# 4                RuO2      0
# ..                ...    ...
# 400            GdNiO3      2
# 401          Sr3Fe2O7      2
# 402         Cu(IrS2)2      2
# 403          Hg2Ru2O7      2
# 404  Ca1.2La2.8Mn4O12      2
#
#                                       struct_file_path  \
# 0    ../data/Structures/Metals/CaCrO3_CollCode_2458...
# 1    ../data/Structures/Metals/CeFe4Sb12_CollCode_6...
# 2    ../data/Structures/Metals/Sm2Mo2O7_CollCode_29...
# 3    ../data/Structures/Metals/LaRu4As12_CollCode_6...
# 4    ../data/Structures/Metals/RuO2_CollCode_15071.cif
# ..                                                 ...
# 400  ../data/Structures/MIT_materials/HighT/GdNiO3_...
# 401  ../data/Structures/MIT_materials/HighT/Sr3Fe2O...
# 402  ../data/Structures/MIT_materials/HighT/CuIr2S4...
# 403  ../data/Structures/MIT_materials/HighT/Hg2Ru2O...
# 404  ../data/Structures/MIT_materials/HighT/La0.7Ca...
#
#      MagpieData minimum Number  MagpieData maximum Number  \
# 0                          8.0                       24.0
# 1                         26.0                       58.0
# 2                          8.0                       62.0
# 3                         33.0                       57.0
# 4                          8.0                       44.0
# ..                         ...                        ...
# 400                        8.0                       64.0
# 401                        8.0                       38.0
# 402                       16.0                       77.0
# 403                        8.0                       80.0
# 404                        8.0                       57.0
#
#      MagpieData range Number  MagpieData mean Number  \
# 0                       16.0               13.600000
# 1                       32.0               45.529412
# 2                       54.0               24.000000
# 3                       24.0               37.000000
# 4                       36.0               20.000000
# ..                       ...                     ...
# 400                     56.0               23.200000
# 401                     30.0               18.500000
# 402                     61.0               35.285714
# 403                     72.0               27.636364
# 404                     49.0               18.980000
#
#      MagpieData avg_dev Number  MagpieData mode Number  \
# 0                     6.720000                     8.0
# 1                     9.190311                    51.0
# 2                    20.363636                     8.0
# 3                     5.647059                    33.0
# 4                    16.000000                     8.0
# ..                         ...                     ...
# 400                  18.240000                     8.0
# 401                  12.250000                     8.0
# 402                  23.836735                    16.0
# 403                  24.991736                     8.0
# 404                  13.176000                     8.0
#
#      MagpieData minimum MendeleevNumber  ...  max_xx_dists  min_xx_dists  \
# 0                                   7.0  ...      3.283740      2.677252
# 1                                  15.0  ...      3.760981      2.904930
# 2                                  23.0  ...      3.073782      2.687974
# 3                                  13.0  ...      3.611906      2.620495
# 4                                  56.0  ...      2.776388      2.467313
# ..                                  ...  ...           ...           ...
# 400                                27.0  ...      3.226412      2.717248
# 401                                 8.0  ...      3.586772      2.756961
# 402                                60.0  ...      3.760108      3.203055
# 403                                56.0  ...      3.654839      2.684031
# 404                                 7.0  ...      3.516261      2.747250
#
#      avg_xx_dists        v_m        v_x        iv    iv_p1  est_hubbard_u  \
# 0        2.813798 -46.438514  25.057295   49.1600   69.460      16.458029
# 1        3.477261 -63.767409  26.543117       NaN      NaN            NaN
# 2        2.898260 -43.966874  23.324578   40.3300   54.417      10.178178
# 3        3.256348 -67.463957  26.631662  110.0000  178.410      65.025073
# 4        2.673363 -44.781726  25.598980   45.0000   59.000       9.927380
# ..            ...        ...        ...       ...      ...            ...
# 400      2.837820 -37.163808  23.507399   35.1870   54.920      15.921411
# 401      2.847590 -44.794374  24.763775   54.9100   75.000      16.452849
# 402      3.484365 -28.508956  21.335783   28.0000   40.000       7.864049
# 403      3.051351 -52.293109  27.009665   59.0000   76.000      13.007450
# 404      2.906344 -39.888114  22.934073   38.9306   57.570      14.915598
#
#      est_charge_trans  volume_per_site
# 0            7.076892        10.539100
# 1                 NaN        22.420575
# 2           12.128367        12.854952
# 3                 NaN        18.114187
# 4           10.334715        10.447064
# ..                ...              ...
# 400         10.413110        10.837428
# 401         -0.397557        12.949911
# 402         20.488443        17.052054
# 403          5.125164        12.063048
# 404          8.843086        11.576092
#
# [405 rows x 168 columns]

# %% [markdown]
# Save the dataset as an Excel spreadsheet

# %%
df_output.to_excel("../data/unprocessed/IMT_Classification_Dataset_Raw_Feature_Set_v10.xlsx", index=False)
